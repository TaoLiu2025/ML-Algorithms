# %%
'''
1. Linear regression
2. logical regression
3. knn
4. k-means
5. svm
6. cnn
7. transformer
'''

# %% [markdown]
# # Logical regression. y = sigmod(z), z = x * w + b
# # loss function: binary cross entropy
